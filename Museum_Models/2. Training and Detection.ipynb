# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_traditionalcap2' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
paths
# Out:
# {'WORKSPACE_PATH': 'Tensorflow\\workspace',
#  'SCRIPTS_PATH': 'Tensorflow\\scripts',
#  'APIMODEL_PATH': 'Tensorflow\\models',
#  'ANNOTATION_PATH': 'Tensorflow\\workspace\\annotations',
#  'IMAGE_PATH': 'Tensorflow\\workspace\\images',
#  'MODEL_PATH': 'Tensorflow\\workspace\\models',
#  'PRETRAINED_MODEL_PATH': 'Tensorflow\\workspace\\pre-trained-models',
#  'CHECKPOINT_PATH': 'Tensorflow\\workspace\\models\\my_ssd_mobnet_traditionalcap2',
#  'OUTPUT_PATH': 'Tensorflow\\workspace\\models\\my_ssd_mobnet_traditionalcap2\\export',
#  'TFJS_PATH': 'Tensorflow\\workspace\\models\\my_ssd_mobnet_traditionalcap2\\tfjsexport',
#  'TFLITE_PATH': 'Tensorflow\\workspace\\models\\my_ssd_mobnet_traditionalcap2\\tfliteexport',
#  'PROTOC_PATH': 'Tensorflow\\protoc'}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}

# %%
import tensorflow as tf

if tf.__version__.startswith("2."):
    print("TensorFlow 2.x is being used.")
else:
    print("TensorFlow 2.x is not being used.")

# %%
import tf_slim as slim

# %%
import tensorflow.compat.v1 as tf

# %%
# !pip install "tensorflow<2.11"

# %%
# !pip install --upgrade h5py

# %%
# !pip install tensorflow

# %%
# !pip list
# Out:
# Package                Version     Editable project location
# ---------------------- ----------- -----------------------------------------------------------------
# absl-py                2.0.0
# altair                 4.2.2
# aniso8601              8.0.0
# anyio                  3.6.2
# asgiref                3.5.2
# asttokens              2.2.1
# attrs                  22.2.0
# backcall               0.2.0
# blinker                1.6.2
# branca                 0.6.0
# cachetools             5.3.0
# certifi                2022.12.7
# charset-normalizer     3.1.0
# click                  8.1.7
# click-plugins          1.1.1
# cligj                  0.7.2
# colorama               0.4.6
# comm                   0.1.4
# contourpy              1.0.7
# cycler                 0.11.0
# debugpy                1.6.7.post1
# decorator              5.1.1
# distlib                0.3.7
# dnspython              2.2.1
# entrypoints            0.4
# executing              1.2.0
# fastapi                0.88.0
# filelock               3.12.2
# Fiona                  1.9.4.post1
# Flask                  2.3.2
# Flask-Cors             4.0.0
# Flask-RESTful          0.3.8
# Flask-SQLAlchemy       3.0.5
# flatbuffers            23.5.26
# folium                 0.14.0
# fonttools              4.39.4
# geopandas              0.13.2
# gitdb                  4.0.10
# GitPython              3.1.31
# greenlet               2.0.2
# h11                    0.14.0
# idna                   3.4
# imgkit                 1.2.3
# importlib-metadata     6.4.1
# ipykernel              6.25.1
# ipython                8.14.0
# itsdangerous           2.1.2
# jedi                   0.19.0
# Jinja2                 3.1.2
# joblib                 1.3.2
# jsonschema             4.17.3
# jupyter_client         8.3.0
# jupyter_core           5.3.1
# keras                  2.15.0
# kiwisolver             1.4.4
# libclang               16.0.6
# Mako                   1.2.4
# markdown-it-py         2.2.0
# MarkupSafe             2.1.3
# matplotlib             3.7.1
# matplotlib-inline      0.1.6
# mdurl                  0.1.2
# motor                  3.1.1
# mysql-connector-python 8.0.28
# nest-asyncio           1.5.7
# nltk                   3.7
# numpy                  1.25.2
# oauthlib               3.2.2
# object-detection       0.1
# packaging              23.1
# pandas                 1.5.3
# parso                  0.8.3
# pickleshare            0.7.5
# Pillow                 9.5.0
# pip                    23.1.2
# pipenv                 2022.11.30
# platformdirs           3.10.0
# prometheus-client      0.17.1
# prompt-toolkit         3.0.39
# protobuf               3.20.3
# psutil                 5.9.5
# pure-eval              0.2.2
# pyarrow                11.0.0
# pycparser              2.21
# pydantic               1.10.2
# pydeck                 0.8.1b0
# Pygments               2.16.1
# pymongo                4.3.3
# Pympler                1.0.1
# pyparsing              3.0.9
# pypiwin32              223
# pyproj                 3.6.0
# pyrsistent             0.19.3
# python-dateutil        2.8.2
# python-json-logger     2.0.7
# pytz                   2023.3
# pytz-deprecation-shim  0.1.0.post0
# pywin32                306
# pyzmq                  25.1.1
# regex                  2022.6.2
# requests               2.31.0
# rich                   13.3.4
# ruamel.yaml.clib       0.2.7
# sacrebleu              2.2.0
# scikit-learn           1.3.0
# scipy                  1.11.2
# setuptools             57.4.0
# shapely                2.0.1
# six                    1.16.0
# sklearn                0.0.post7
# slim                   0.1         d:\github\museum_object_detection\tensorflow\models\research\slim
# smmap                  5.0.0
# sniffio                1.3.0
# SQLAlchemy             2.0.20
# stack-data             0.6.2
# starlette              0.22.0
# streamlit              1.21.0
# tenacity               8.2.3
# tf-slim                1.1.0
# threadpoolctl          3.2.0
# toml                   0.10.2
# toolz                  0.12.0
# tornado                6.3.3
# tqdm                   4.64.0
# traitlets              5.9.0
# typing_extensions      4.7.1
# tzdata                 2023.3
# tzlocal                4.3
# urllib3                1.26.15
# uvicorn                0.14.0
# validators             0.20.0
# virtualenv             20.24.3
# virtualenv-clone       0.5.7
# watchdog               3.0.0
# wcwidth                0.2.6
# Werkzeug               2.3.7
# wget                   3.2
# wheel                  0.41.3
# wrapt                  1.14.1
# zipp                   3.15.0
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip

# %%
import tensorflow.compat.v1 as tf

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'ThumbsUp', 'id':1}, {'name':'ThumbsDown', 'id':2}, {'name':'ThankYou', 'id':3}, {'name':'LiveLong', 'id':4}, {'name':'TraditionalCap', 'id':5}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}
# Out:
# x Tensorflow/workspace/images/train/
# x Tensorflow/workspace/images/train/20231026_102603.jpg
# x Tensorflow/workspace/images/train/20231026_102603.xml
# x Tensorflow/workspace/images/train/20231026_102604.jpg
# x Tensorflow/workspace/images/train/20231026_102604.xml
# x Tensorflow/workspace/images/train/20231026_102605.jpg
# x Tensorflow/workspace/images/train/20231026_102605.xml
# x Tensorflow/workspace/images/train/20231026_102606.jpg
# x Tensorflow/workspace/images/train/20231026_102606.xml
# x Tensorflow/workspace/images/train/20231026_102607.jpg
# x Tensorflow/workspace/images/train/20231026_102607.xml
# x Tensorflow/workspace/images/train/20231026_102609.jpg
# x Tensorflow/workspace/images/train/20231026_102609.xml
# x Tensorflow/workspace/images/train/20231026_102610.jpg
# x Tensorflow/workspace/images/train/20231026_102610.xml
# x Tensorflow/workspace/images/train/20231026_102611.jpg
# x Tensorflow/workspace/images/train/20231026_102611.xml
# x Tensorflow/workspace/images/train/20231026_102612.jpg
# x Tensorflow/workspace/images/train/20231026_102612.xml
# x Tensorflow/workspace/images/train/20231026_102614.jpg
# x Tensorflow/workspace/images/train/20231026_102614.xml
# x Tensorflow/workspace/images/train/livelong.bdb70008-7182-11ee-aabf-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/livelong.bdb70008-7182-11ee-aabf-c809a8702b77.xml
# x Tensorflow/workspace/images/train/livelong.beec05e9-7182-11ee-bd50-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/livelong.beec05e9-7182-11ee-bd50-c809a8702b77.xml
# x Tensorflow/workspace/images/train/livelong.c15cd33b-7182-11ee-b7cc-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/livelong.c15cd33b-7182-11ee-b7cc-c809a8702b77.xml
# x Tensorflow/workspace/images/train/livelong.c2949d80-7182-11ee-ad48-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/livelong.c2949d80-7182-11ee-ad48-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thankyou.b32af929-7182-11ee-bca3-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thankyou.b32af929-7182-11ee-bca3-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thankyou.b460da54-7182-11ee-963f-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thankyou.b460da54-7182-11ee-963f-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thankyou.b596d476-7182-11ee-9ec0-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thankyou.b596d476-7182-11ee-9ec0-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thankyou.b6cdaec8-7182-11ee-ae46-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thankyou.b6cdaec8-7182-11ee-ae46-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsdown.a88986e7-7182-11ee-b71b-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsdown.a88986e7-7182-11ee-b71b-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsdown.a9c0a70d-7182-11ee-b5be-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsdown.a9c0a70d-7182-11ee-b5be-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsdown.aaf710f4-7182-11ee-8197-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsdown.aaf710f4-7182-11ee-8197-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsdown.ac301c1e-7182-11ee-9c07-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsdown.ac301c1e-7182-11ee-9c07-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsup.46dbd44f-7183-11ee-a9b2-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsup.46dbd44f-7183-11ee-a9b2-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsup.4a7c68d4-7183-11ee-8823-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsup.4a7c68d4-7183-11ee-8823-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsup.9e04170c-7182-11ee-a9d6-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsup.9e04170c-7182-11ee-a9d6-c809a8702b77.xml
# x Tensorflow/workspace/images/train/thumbsup.9f3ef385-7182-11ee-a04b-c809a8702b77.jpg
# x Tensorflow/workspace/images/train/thumbsup.9f3ef385-7182-11ee-a04b-c809a8702b77.xml
# x Tensorflow/workspace/images/test/
# x Tensorflow/workspace/images/test/20231026_102615.jpg
# x Tensorflow/workspace/images/test/20231026_102615.xml
# x Tensorflow/workspace/images/test/20231026_102622.jpg
# x Tensorflow/workspace/images/test/20231026_102622.xml
# x Tensorflow/workspace/images/test/livelong.c0251150-7182-11ee-9890-c809a8702b77.jpg
# x Tensorflow/workspace/images/test/livelong.c0251150-7182-11ee-9890-c809a8702b77.xml
# x Tensorflow/workspace/images/test/thankyou.b802d200-7182-11ee-86a7-c809a8702b77.jpg
# x Tensorflow/workspace/images/test/thankyou.b802d200-7182-11ee-86a7-c809a8702b77.xml
# x Tensorflow/workspace/images/test/thumbsdown.ad68c69b-7182-11ee-94ef-c809a8702b77.jpg
# x Tensorflow/workspace/images/test/thumbsdown.ad68c69b-7182-11ee-94ef-c809a8702b77.xml
# x Tensorflow/workspace/images/test/thumbsup.4811a10e-7183-11ee-a744-c809a8702b77.jpg
# x Tensorflow/workspace/images/test/thumbsup.4811a10e-7183-11ee-a744-c809a8702b77.xml
# x Tensorflow/workspace/images/test/thumbsup.49467495-7183-11ee-8e2d-c809a8702b77.jpg
# x Tensorflow/workspace/images/test/thumbsup.49467495-7183-11ee-8e2d-c809a8702b77.xml

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
labels
# Out:
# [{'name': 'ThumbsUp', 'id': 1},
#  {'name': 'ThumbsDown', 'id': 2},
#  {'name': 'ThankYou', 'id': 3},
#  {'name': 'LiveLong', 'id': 4},
#  {'name': 'TraditionalCap', 'id': 5}]

# %%
pipeline_config.model.ssd.num_classes = len(labels)
# update number of classes
pipeline_config.train_config.batch_size = 5
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2 --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2 --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2

# %%
# !{command}
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1107 17:20:51.836725 23468 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 2000
# I1107 17:20:51.931702 23468 config_util.py:552] Maybe overwriting train_steps: 2000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1107 17:20:51.932705 23468 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1107 17:20:52.230131 23468 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I1107 17:20:52.409336 23468 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I1107 17:20:52.411307 23468 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1107 17:20:52.412302 23468 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1107 17:20:52.413342 23468 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1107 17:20:52.573641 23468 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1107 17:20:52.819692 23468 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1107 17:21:13.839429 23468 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1107 17:21:24.128516 23468 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1107 17:21:30.618705 23468 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1107 17:22:49.586026 13888 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1107 17:23:35.991866  2600 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# W1107 17:26:58.044108 23468 checkpoint.py:204] Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# W1107 17:26:58.044108 23468 checkpoint.py:213] Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# W1107 17:26:58.044108 23468 checkpoint.py:213] Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# W1107 17:26:58.045113 23468 checkpoint.py:213] Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1107 17:23:47.657176 21500 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1107 17:23:47.658127 21500 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1107 17:23:47.658127 21500 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1107 17:23:47.658127 21500 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1107 17:23:47.659122 21500 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# I1107 17:24:40.084109 21500 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# I1107 17:24:40.179779 21500 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1107 17:24:40.180841 21500 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1107 17:24:40.182176 21500 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1107 17:24:40.297693 21500 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1107 17:24:45.239115 21500 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1107 17:25:43.949828 21500 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1107 17:25:48.586441 21500 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2
# I1107 17:26:07.676110 21500 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2
# INFO:tensorflow:Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2\ckpt-3
# I1107 17:26:07.703566 21500 checkpoint_utils.py:151] Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2\ckpt-3
# D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1107 17:26:23.697232 21500 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1107 17:27:07.081273 21500 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1107 17:27:31.185843 21500 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Traceback (most recent call last):
#   File "D:\GitHub\Museum_Object_Detection\Tensorflow\models\research\object_detection\model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\platform\app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "D:\GitHub\Museum_Object_Detection\Tensorflow\models\research\object_detection\model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py", line 1158, in eval_continuously
#     eager_eval_loop(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py", line 954, in eager_eval_loop
#     eval_dict, class_agnostic = prepare_eval_dict(local_prediction_dict,
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py", line 813, in prepare_eval_dict
#     eval_dict = eval_util.result_dict_for_batched_example(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\eval_util.py", line 1044, in result_dict_for_batched_example
#     shape_utils.static_or_dynamic_map_fn(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\utils\shape_utils.py", line 239, in static_or_dynamic_map_fn
#     outputs = [fn(arg_tuple) for arg_tuple in arg_tuples]
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\utils\shape_utils.py", line 239, in <listcomp>
#     outputs = [fn(arg_tuple) for arg_tuple in arg_tuples]
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\eval_util.py", line 550, in _scale_box_to_absolute
#     return box_list_ops.to_absolute_coordinates(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\core\box_list_ops.py", line 913, in to_absolute_coordinates
#     max_assert = tf.Assert(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\ops\control_flow_ops.py", line 156, in Assert
#     raise errors.InvalidArgumentError(
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Expected 'tf.Tensor(False, shape=(), dtype=bool)' to be true. Summarized data: b'maximum box coordinate value is larger than 1.100000: '
# 1.2008449
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1107 17:23:47.632182 21752 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1107 17:23:47.632182 21752 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1107 17:23:47.633303 21752 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1107 17:23:47.633303 21752 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1107 17:23:47.633303 21752 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# I1107 17:24:47.355701 21752 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# I1107 17:24:47.357692 21752 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1107 17:24:47.359695 21752 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1107 17:24:47.362692 21752 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1107 17:24:47.432770 21752 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1107 17:24:47.782706 21752 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1107 17:25:45.530105 21752 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1107 17:25:50.694839 21752 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2
# I1107 17:26:09.180762 21752 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2
# INFO:tensorflow:Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2\ckpt-3
# I1107 17:26:09.181761 21752 checkpoint_utils.py:151] Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_traditionalcap2\ckpt-3
# D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1107 17:26:25.103885 21752 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1107 17:27:08.974642 21752 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1107 17:27:32.216515 21752 deprecation.py:350] From D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Traceback (most recent call last):
#   File "D:\GitHub\Museum_Object_Detection\Tensorflow\models\research\object_detection\model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\platform\app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "D:\GitHub\Museum_Object_Detection\Tensorflow\models\research\object_detection\model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py", line 1158, in eval_continuously
#     eager_eval_loop(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py", line 954, in eager_eval_loop
#     eval_dict, class_agnostic = prepare_eval_dict(local_prediction_dict,
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py", line 813, in prepare_eval_dict
#     eval_dict = eval_util.result_dict_for_batched_example(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\eval_util.py", line 1044, in result_dict_for_batched_example
#     shape_utils.static_or_dynamic_map_fn(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\utils\shape_utils.py", line 239, in static_or_dynamic_map_fn
#     outputs = [fn(arg_tuple) for arg_tuple in arg_tuples]
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\utils\shape_utils.py", line 239, in <listcomp>
#     outputs = [fn(arg_tuple) for arg_tuple in arg_tuples]
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\eval_util.py", line 550, in _scale_box_to_absolute
#     return box_list_ops.to_absolute_coordinates(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\core\box_list_ops.py", line 913, in to_absolute_coordinates
#     max_assert = tf.Assert(
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\util\traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "D:\GitHub\Museum_Object_Detection\tfod\lib\site-packages\tensorflow\python\ops\control_flow_ops.py", line 156, in Assert
#     raise errors.InvalidArgumentError(
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Expected 'tf.Tensor(False, shape=(), dtype=bool)' to be true. Summarized data: b'maximum box coordinate value is larger than 1.100000: '
# 1.2008449

# %%
# tensorboard - loss matrix
#(tfod) D:\GitHub\Museum_Object_Detection\Tensorflow\workspace\models\my_ssd_mobnet\train>tensorboard --logdir=.

# tensorboard - Evaluation matrix
# (tfod) D:\GitHub\Museum_Object_Detection\Tensorflow\workspace\models\my_ssd_mobnet\eval>tensorboard --logdir=.

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
# 'ckpt-3' -latest checkpoint in D:\GitHub\Museum_Object_Detection\Tensorflow\workspace\models\my_ssd_mobnet
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '20231026_102622.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from object_detection.utils import visualization_utils as viz_utils

# Load the image
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

# Resize the image for visualization
# You can adjust the new size as needed
new_height, new_width = 1000, 800  # Example dimensions
image_np = cv2.resize(image_np, (new_width, new_height))

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy() for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
    image_np_with_detections,
    detections['detection_boxes'],
    detections['detection_classes'] + label_id_offset,
    detections['detection_scores'],
    category_index,
    use_normalized_coordinates=True,
    max_boxes_to_draw=5,
    min_score_thresh=.8,
    agnostic_mode=False
)

# Show the resized and annotated image
plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Load the label map file.
label_map = tf.io.gfile.GFile(files['LABELMAP'], 'r').read()
label_map

# Create a dictionary to map label IDs to label names.
# label_id_to_name_map = {}
# for item in label_map.item:
#   label_id = item.id
#   label_name = item.name
#   label_id_to_name_map[label_id] = label_name

# Read the image.
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

# Resize the image for visualization
new_height, new_width = 1000, 800
image_np = cv2.resize(image_np, (new_width, new_height))

# Convert the image to a Tensor.
input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)

# Detect objects in the image.
detections = detect_fn(input_tensor)

# Get the number of detections.
num_detections = int(detections.pop('num_detections'))

# Get the detection boxes and classes.
detection_boxes = detections['detection_boxes'].numpy()
detection_classes = detections['detection_classes'].numpy()

# Convert the detection classes to integers.
detection_classes = detection_classes.astype(np.int64)

# Add one to the detection classes to account for the label ID offset.
detection_classes += 1

# Get the label names for the detections.
label_names = []
for detection_class in detection_classes:
    for num in detection_class:
        label_name = labels[num-1]['name']
        label_names.append(label_name)

# Visualize the detections on the image.
# viz_utils.visualize_boxes_and_labels_on_image_array(
#     image_np_with_detections,
#     detection_boxes,
#     label_names,
#     detections['detection_scores'],
#     category_index,
#     use_normalized_coordinates=True,
#     max_boxes_to_draw=5,
#     min_score_thresh=.8,
#     agnostic_mode=False)

# Display the image.
plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
label_names
# Out:
# ['TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThankYou',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThumbsDown',
#  'LiveLong',
#  'TraditionalCap',
#  'ThankYou',
#  'TraditionalCap',
#  'ThankYou',
#  'TraditionalCap',
#  'ThumbsUp',
#  'TraditionalCap',
#  'ThankYou',
#  'ThankYou',
#  'TraditionalCap',
#  'ThumbsDown',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThankYou',
#  'ThankYou',
#  'ThankYou',
#  'ThankYou',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThumbsUp',
#  'ThumbsUp',
#  'ThankYou',
#  'ThankYou',
#  'LiveLong',
#  'ThankYou',
#  'LiveLong',
#  'TraditionalCap',
#  'ThankYou',
#  'ThankYou',
#  'ThumbsDown',
#  'ThankYou',
#  'ThankYou',
#  'ThankYou',
#  'ThumbsUp',
#  'TraditionalCap',
#  'ThankYou',
#  'ThankYou',
#  'TraditionalCap',
#  'ThumbsUp',
#  'TraditionalCap',
#  'ThankYou',
#  'ThankYou',
#  'ThumbsUp',
#  'ThumbsUp',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThumbsUp',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThankYou',
#  'TraditionalCap',
#  'ThankYou',
#  'ThankYou',
#  'ThankYou',
#  'TraditionalCap',
#  'LiveLong',
#  'ThankYou',
#  'LiveLong',
#  'ThumbsDown',
#  'TraditionalCap',
#  'ThumbsDown',
#  'ThumbsUp',
#  'ThumbsUp',
#  'ThankYou',
#  'ThumbsUp',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThankYou',
#  'ThumbsUp',
#  'ThankYou',
#  'LiveLong',
#  'TraditionalCap',
#  'TraditionalCap',
#  'TraditionalCap',
#  'ThankYou',
#  'ThumbsDown',
#  'ThumbsUp',
#  'TraditionalCap',
#  'ThumbsDown']

# %%
highest_label = max(label_names, key=label_names.count)
highest_label
# Out:
# 'TraditionalCap'

# %%
tf.io.gfile.glob("path/to/train.record*")
tf.io.gfile.glob("path/to/test.record*")

# %%
detection_classes

# %%
labels[1]
# labels[1]['name']

# %%
for detection_class in detection_classes:
    for num in detection_class:
        print(num)

# %%
# Get the detected bounding boxes and labels.
detections = detect_fn(input_tensor)

# Create a new variable to store the detected label.
detected_label = None

# Get the value of the detection_classes key.
detection_classes = detections['detection_classes']

# Get the index of the highest scoring bounding box.
highest_scoring_bbox_index = np.argmax(detections['detection_scores'])

# Get the detected label for the highest scoring bounding box.
detected_label = detection_classes[highest_scoring_bbox_index]

# Print the detected label.
print(detected_label)

# %%
# Load the label map file.
label_map = tf.io.gfile.GFile('path/to/label_map.pbtxt', 'r').read()

# Create a dictionary to map label IDs to label names.
label_id_to_name_map = {}
for item in label_map.item:
  label_id = item.id
  label_name = item.name
  label_id_to_name_map[label_id] = label_name

# Get the label IDs for the bounding boxes.
label_ids = tf.cast(detections['detection_classes'], tf.int32).numpy()

# Look up the label names in the dictionary.
label_names = []
for label_id in label_ids:
  label_name = label_id_to_name_map[label_id]
  label_names.append(label_name)

# Print the label names.
for label_name in label_names:
  print(label_name)

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cap = cv2.VideoCapture(0)
#       2 width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#       3 height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#
# NameError: name 'cv2' is not defined

# %%
# close - q

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
